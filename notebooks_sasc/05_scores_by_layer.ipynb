# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import sys
from IPython.display import display, HTML
from typing import List
import numpy as np
import pandas as pd
import joblib
from sklearn.linear_model import RidgeCV
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sasc.config

# %%
RESULTS_DIR = join(sasc.config.RESULTS_DIR)
expls_scores_bert = joblib.load(join(RESULTS_DIR, 'bert', 'wiki_norm_std', 'wiki_our_syn_perc_std_score.pkl'))

# %%
df_f_llama = pd.read_pickle(join(RESULTS_DIR, 'results_fmri_full_1500_llama.pkl'))
df_f_opt = pd.read_pickle(join(RESULTS_DIR, 'results_fmri_full_1500_opt.pkl'))

# %%
# # display all rows
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(df_fmri['roi_func'].value_counts())

# %%
def get_layer_rep_and_scores(df_f, suffix=" (OPT)"):
    # build related df
    expls_fmri = df_f["top_explanation_init_strs"].values.tolist()
    df_fmri = pd.DataFrame.from_dict(
        {
            "layer": "fmri",
            "score": df_f["top_score_normalized"].values,
            "expl": expls_fmri,
            "roi_func": df_f["roi_func"].values,
        }
    )

    # make each roi into one-hot column
    unique_rois = sorted(
        set(
            sum(
                [
                    [None if x == "--" else x for x in roi_func]
                    for roi_func in df_f["roi_func"].values
                ],
                [],
            )
        )
    )
    unique_rois.remove("-")
    for k in unique_rois:
        df_fmri[f"roi___{k}"] = df_f["roi_func"].apply(lambda x: k in x)
    cols_fmri_top = (
        df_fmri[[k for k in df_fmri.columns if k.startswith("roi___")]]
        .sum()
        .sort_values(ascending=False)
        .index[:6]
    )
    layer_rep = []
    scores_fmri_top = []
    for col in cols_fmri_top:
        d = df_fmri[df_fmri[col]]
        # print(d.shape)
        layer_rep += [col.replace("roi___", "").replace("S2F", "PO") + suffix] * d.shape[0]
        scores_fmri_top += d["score"].values.tolist()
    return layer_rep, scores_fmri_top


layer_rep_llama, scores_llama_top = get_layer_rep_and_scores(df_f_llama, suffix="")
layer_rep_opt, scores_opt_top = get_layer_rep_and_scores(df_f_opt, suffix=" (OPT)")

# %% [markdown]
# # Make boxplots

# %%
# set up df
sns.set_theme(style="ticks")
layer = sum(
    [
        [f"BERT {i}"] * expls_scores_bert.shape[1]
        for i in range(expls_scores_bert.shape[0])
    ],
    [],
)
df_bert_plot = pd.DataFrame.from_dict(
    {
        "layer": layer,
        "score": expls_scores_bert.flatten(),
    }
)
df_llama_plot = pd.DataFrame.from_dict(
    {
        "layer": layer_rep_llama,
        "score": np.array(scores_llama_top)
    }
)
df_opt_plot = pd.DataFrame.from_dict(
    {
        "layer": layer_rep_opt,
        "score": np.array(scores_opt_top)
    }
)

df = pd.concat([df_bert_plot, df_llama_plot]).reset_index()

# # make plot
lay = df["layer"].unique()
n1 = len(df_bert_plot['layer'].unique())
n2 = len(df_llama_plot['layer'].unique())
hues = sns.color_palette("Blues", int(1.3 * n1))[1:][:n1] \
    + sns.color_palette("Reds", int(1.3 * n2))[1:][:n2]
    # + sns.color_palette("Reds", int(1.3 * n2))[1:][:n2]
palette = dict(zip(lay, hues))

f, ax = plt.subplots(figsize=(6, 3.5), dpi=300)
sns.boxplot(
    x="score",
    y="layer",
    data=df,
    width=0.6,
    whis=[0, 100],
    # palette="vlag",
    hue="layer",
    palette=palette,
    dodge=False,
)
plt.legend([], [], frameon=False)
# , whis=0, fliersize=0)
plt.xlim(-1, 6)

# Add in points to show each observation
# sns.stripplot(x="score", y="layer", data=df,
#   size=1.3, color=".5", linewidth=0, alpha=0.1, legend=False)

ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
plt.xlabel("Explanation score ($\sigma_f$)")
plt.ylabel("BERT layer")
plt.yticks(fontsize="small")
# plt.savefig(join(RESULTS_DIR, "wiki_our_syn_perc_score_boxplot.png"))
plt.savefig(
    join(RESULTS_DIR, 'bert', 'wiki_norm_std', "wiki_our_syn_perc_score_boxplot.pdf"), bbox_inches="tight"
)

# %% [markdown]
# # Joyplot

# %%
# make a joyplot of each row of the scores expls_scores_bert
fig = plt.figure(figsize=(12, 6))
n = len(expls_scores_bert)
for i in range(len(expls_scores_bert)):
    ax = plt.subplot(n, 1, i+1)
    sns.kdeplot(expls_scores_bert[i], fill=True)

    if i < n - 1:
        plt.xticks([])
    plt.yticks([0], labels=['Layer ' + str(i)], fontsize='xx-small')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_alpha(0.3)
    plt.xlim(-20, 40)
    plt.ylabel('')
fig = plt.gcf()
fig.subplots_adjust(hspace=-2)
fig.supxlabel('Synthetic score')
fig.supylabel('Layer')
plt.show()
