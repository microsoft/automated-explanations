# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
from typing import List
import numpy as np
import sys
sys.path.append('..')
import json
EXPT_NAME = 'uts02_concepts_pilot_mar22'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
r = (pd.read_pickle('../../results/results/fmri_results_merged.pkl')
    .sort_values(by=['top_score_synthetic'], ascending=False))
r['id'] = "('" + r['top_explanation_init_strs'].str.replace(' ', '_').str.slice(stop=20) + "', '" + r['subject'] + "', " + r['module_num'].astype(str) + "),"
r = r[r.subject == 'UTS02']

# %%
D = {
'temporal': [
   ('moments', 'UTS02', 337),	
   ('moments', 'UTS02', 200),	
   ('time period', 'UTS02', 271),	
   ('time period', 'UTS02', 274),	
   ('time period', 'UTS02', 429),	
   ('time period', 'UTS02', 114),	
   ('time period', 'UTS02', 370),
   ('time period', 'UTS02', 362),	
   ('time period', 'UTS02', 149),	
   ('time period', 'UTS02', 16),
   ('time period', 'UTS02', 263),	
   ('time period', 'UTS02', 231),	
   ('time period', 'UTS02', 151),	
   ('time period', 'UTS02', 197),	
   ('time period', 'UTS02', 397),	
	('time period', 'UTS02', 412),	
   ('time period', 'UTS02', 424),	
   ('time period', 'UTS02', 425),	
   ('time period', 'UTS02', 460),	
   ('time period', 'UTS02', 5),	
   ('time period', 'UTS02', 54),	
   ('time period', 'UTS02', 63),	
   ('time period', 'UTS02', 115),	
   ('time period', 'UTS02', 120),	
   ('time period', 'UTS02', 24),	
   ('time period', 'UTS02', 470),	
   ('time period', 'UTS02', 480),	
   ('time period', 'UTS02', 52),	
   ('time period', 'UTS02', 184),	
   ('time period', 'UTS02', 349),	   
   ('time period', 'UTS02', 483),	

   # age
   ('age', 'UTS02', 198),	('age', 'UTS02', 223),	('age', 'UTS02', 247),	('age', 'UTS02', 304),	('age', 'UTS02', 360),	('age', 'UTS02', 380),	('age', 'UTS02', 39),	('age', 'UTS02', 438),	('age', 'UTS02', 471),	('age', 'UTS02', 486),	('age', 'UTS02', 236),	('age', 'UTS02', 379),	('age', 'UTS02', 401),	('age', 'UTS02', 334),
   # ('birthdays', 'UTS02', 442),	

   ('time passing', 'UTS02', 464),	('time', 'UTS02', 212),
   ('time', 'UTS02', 240),	

   ('time passing', 'UTS02', 4),	('time passing', 'UTS02', 19),	('time passing', 'UTS02', 320),	('time passing', 'UTS02', 369),	('time passing', 'UTS02', 394),	('time passing', 'UTS02', 405),	('time passing', 'UTS02', 57),
   ('time', 'UTS02', 335),	('time', 'UTS02', 59),	('time_passing', 'UTS02', 164),	('time_passing', 'UTS02', 498),
   ('time period', 'UTS02', 251),	
],
'numeric': [
   ('measurements', 'UTS02', 171), 
   ('measurements', 'UTS02', 359),	('measurements', 'UTS02', 307),	('measurements', 'UTS02', 48),	('measurements', 'UTS02', 22),	('measurements', 'UTS02', 478),	('measurements', 'UTS02', 341),
   ('numbers', 'UTS02', 170),	('numbers', 'UTS02', 191),	('numbers', 'UTS02', 350),	('numbers', 'UTS02', 55),	('numbers', 'UTS02', 162),	('numbers', 'UTS02', 38),
],
'locational': [
    ('locations', 'UTS02', 136),	('locations', 'UTS02', 260),	('locations', 'UTS02', 107),	
    ('locations', 'UTS02', 235),	('locations', 'UTS02', 113),	
   ('locations', 'UTS02', 336),	
   ('locations', 'UTS02', 276),	('locations', 'UTS02', 303),	('locations', 'UTS02', 310),	('locations', 'UTS02', 368),	('locations', 'UTS02', 391),	('locations', 'UTS02', 122),	('locations', 'UTS02', 118),	('locations', 'UTS02', 243),	('locations', 'UTS02', 249),	('locations', 'UTS02', 315),	('locations', 'UTS02', 40),	('locations', 'UTS02', 67),
   ('locations', 'UTS02', 153),	
   ('locations', 'UTS02', 15),	
],
'emotional': [
   ('joy or suriprise', 'UTS02', 62),	
   ("emotional reactions", 'UTS02', 230),	('emotional reactions', 'UTS02', 452),	
   ('emotional reactions', 'UTS02', 280),	('fear', 'UTS02', 140),	('negative emotional reactions', 'UTS02', 88),	
   ('emtional reactions', 'UTS02', 294),	
   ('emtional reactions', 'UTS02', 23),	('emotional reactions', 'UTS02', 239),
   ('emtion', 'UTS02', 259),	
   ('emotion', 'UTS02', 423),	('emotion', 'UTS02', 179),	('emotion', 'UTS02', 45),	('emotion', 'UTS02', 208),	('emotional expression', 'UTS02', 289),	('emotional expression', 'UTS02', 32),	('emotional expression', 'UTS02', 398),	('emotional response', 'UTS02', 241),	('emotional response', 'UTS02', 435),	('emotional response', 'UTS02', 206),	('emotions', 'UTS02', 253),	('emotions', 'UTS02', 92),	('emotions', 'UTS02', 60),

   ('emotional reaction', 'UTS02', 367),	('emotional reaction', 'UTS02', 378),	('emotional reaction', 'UTS02', 89),	('surprise', 'UTS02', 11),
   ('fear', 'UTS02', 396),	('fear', 'UTS02', 195),	('emotions', 'UTS02', 104),	('emotions', 'UTS02', 227),

   ('laughter', 'UTS02', 34),	('laughter', 'UTS02', 102),	('laughter', 'UTS02', 139),	('laughter', 'UTS02', 190),	('laughter', 'UTS02', 229),	('laughter', 'UTS02', 295),	('laughter', 'UTS02', 426),	('laughter', 'UTS02', 490),
   ('loneliness', 'UTS02', 13),	('loneliness', 'UTS02', 476),
   ('negative emotional reactions', 'UTS02', 232),	
   ('physical affection', 'UTS02', 488),	
   ('surprise', 'UTS02', 168),	
],
'social': [
    ('communication', 'UTS02', 163),	('communication', 'UTS02', 169),	('communication', 'UTS02', 182),	('communication', 'UTS02', 196),	('communication', 'UTS02', 299),	('communication', 'UTS02', 332),	('communication', 'UTS02', 373),	('communication', 'UTS02', 419),	('communication', 'UTS02', 427),	('communication', 'UTS02', 446),	('communication', 'UTS02', 473),	('communication', 'UTS02', 47),	('communication', 'UTS02', 312),	('communication', 'UTS02', 44),	('communication', 'UTS02', 492),	('communication', 'UTS02', 95),	('communication', 'UTS02', 393),	('communication', 'UTS02', 357),	('communication', 'UTS02', 399),	('communication', 'UTS02', 345),
   ('dating', 'UTS02', 185),	
   ('dialogue', 'UTS02', 21),	
   ('dialogue', 'UTS02', 42),	('dialogue', 'UTS02', 73),	('dialogue', 'UTS02', 189),	('dialogue', 'UTS02', 321),	('dialogue', 'UTS02', 296),
   ('family and friends', 'UTS02', 124),	('family and friends', 'UTS02', 203),	('family and friends', 'UTS02', 404),	('family relationships', 'UTS02', 30),	('family relationships', 'UTS02', 33),
   ('interpersonal interactions', 'UTS02', 3),	('interpersonal interactions', 'UTS02', 76),	('interpersonal interactions', 'UTS02', 254),	('interpersonal interactions', 'UTS02', 261),
   ('marriage', 'UTS02', 255),	('marriage', 'UTS02', 361),	('marriage', 'UTS02', 375),
   ('relationships', 'UTS02', 387),	
   ('interpersonal interactions', 'UTS02', 172),	('interpersonal interactions', 'UTS02', 308),	('interpersonal interactions', 'UTS02', 135),
   ('relationships', 'UTS02', 108),	('relationships', 'UTS02', 150),	('relationships', 'UTS02', 448),	('relationships', 'UTS02', 477),	('relationships', 'UTS02', 485),	('relationships', 'UTS02', 49),	('relationships', 'UTS02', 91),	('relationships,_as_ma', 'UTS02', 331),	('relationships,_eithe', 'UTS02', 31),	('relationships,_eithe', 'UTS02', 463),	('relationships,_intim', 'UTS02', 75),	('relationships,_marri', 'UTS02', 313),	('relationships,_parti', 'UTS02', 333),	('relationships,_parti', 'UTS02', 402),	('relationships,_speci', 'UTS02', 193),	('relationships,_speci', 'UTS02', 194),	('relationships,_such_', 'UTS02', 138),	('relationships,_such_', 'UTS02', 266),	('relationships_and/or', 'UTS02', 148),	('relationships_and/or', 'UTS02', 437),	('relationships_and_ag', 'UTS02', 2),	('relationships_and_br', 'UTS02', 413),	('relationships_and_co', 'UTS02', 222),	('relationships_and_da', 'UTS02', 204),	('relationships_and_em', 'UTS02', 250),	('relationships_and_em', 'UTS02', 407),	('relationships_and_em', 'UTS02', 487),	('relationships_and_fo', 'UTS02', 121),	('relationships_and_gr', 'UTS02', 258),	('relationships_and_id', 'UTS02', 400),	('relationships_and_in', 'UTS02', 246),	('relationships_and_in', 'UTS02', 385),	('relationships_and_in', 'UTS02', 7),	('relationships_and_li', 'UTS02', 9),	('relationships_and_lo', 'UTS02', 314),	('relationships_and_ma', 'UTS02', 178),	('relationships_and_ma', 'UTS02', 20),	('relationships_and_pe', 'UTS02', 330),	('relationships_betwee', 'UTS02', 0),	('relationships_betwee', 'UTS02', 65),	('relationships_with_f', 'UTS02', 288),
],
# 'professional': [
#    ('education_or_career-', 'UTS02', 351),	
#    ('finding_or_maintaini', 'UTS02', 137),	
#    ('people_engaging_in_a', 'UTS02', 144),	
#    ('professions_and/or_r', 'UTS02', 475),	
#    ('work_and_professions', 'UTS02', 93),	
# ],

# extra labels
'food': [
  ('food', 'UTS02', 1),	('food and drinks', 'UTS02', 101),	('food and drinks', 'UTS02', 451),	('food items', 'UTS02', 292),	('food items', 'UTS02', 46),	('food preparation', 'UTS02', 181),	('food preparation', 'UTS02', 79),	  
#   ('food items', 'UTS02', 286),	('food items', 'UTS02', 415),	
],
# 'movement': [
#    ('movement', 'UTS02', 147),	('movement', 'UTS02', 166),	('movement', 'UTS02', 214),	('movement', 'UTS02', 26),	('movement', 'UTS02', 318),	('movement', 'UTS02', 456),	('movement', 'UTS02', 493),	('movement', 'UTS02', 64),	('movement,_either_of_', 'UTS02', 388),	('movement,_either_of_', 'UTS02', 80),	('movement,_either_wal', 'UTS02', 319),	('movement_and_transit', 'UTS02', 381),	('movement_from_one_pl', 'UTS02', 491),	('movement_in_a_partic', 'UTS02', 285),	('movement_or_action', 'UTS02', 489),	('movement_or_change_i', 'UTS02', 267),	('movement_or_change_i', 'UTS02', 411),	('movement_or_location', 'UTS02', 100),	('movement_or_motion', 'UTS02', 25),	('movement_or_travel', 'UTS02', 142),	('movement_or_travel', 'UTS02', 256),
#    ('physical_contact', 'UTS02', 242),	('physical_contact', 'UTS02', 262),	('physical_contact', 'UTS02', 410),	('physical_contact', 'UTS02', 453),	('physical_contact_or_', 'UTS02', 323),	('physical_contact_or_', 'UTS02', 374),	('physical_contact_or_', 'UTS02', 74),	('physical_contact_or_', 'UTS02', 90),
# ],
# 'violent': [
#     ('physical_pain_and_in', 'UTS02', 157),	
# ],
'repetition': [
    ('repetition', 'UTS02', 109),	('repetition', 'UTS02', 173),	('repetition', 'UTS02', 180),	('repetition', 'UTS02', 224),	('repetition', 'UTS02', 225),	('repetition', 'UTS02', 306),	('repetition', 'UTS02', 358),	('repetition', 'UTS02', 41),	('repetition', 'UTS02', 474),	('repetition', 'UTS02', 494),	('repetition', 'UTS02', 160),	('repetition', 'UTS02', 440),	('repetition', 'UTS02', 444),
],
# 'sounds': [
#     ('sound', 'UTS02', 81),	('sound_or_action_that', 'UTS02', 311),	('sound_or_noise,_such', 'UTS02', 83),	('sound_or_ringing,_su', 'UTS02', 77),	('spoken_phrases', 'UTS02', 346),
# ],



# manual
'manual': [
   ('death', 'UTS02', 155),
   ('negativity', 'UTS02', 248),
   ('physical injury or trauma', 'UTS02', 339),
   ('hair and clothing', 'UTS02', 154),
   ('birthdays', 'UTS02', 442),
   ('rejection', 'UTS02', 342),
   
]

}
json.dump(D, open(f'{EXPT_NAME}.json', 'w'), indent=0) #, indent=4)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', 200):
    display(r[['id', 'top_explanation_init_strs']].sort_values(by='id').transpose())
# Out:
#                                                                                        6    \
# id                                                  ('a_feeling_of_joy,_su', 'UTS02', 62),
# top_explanation_init_strs  a feeling of joy, surprise, relief, satisfaction, and amazement
#
#                                                                   916  \
# id                            ('a_focus_on_looking_u', 'UTS02', 156),
# top_explanation_init_strs  a focus on looking up or towards something
#
#                                                                                                               728  \
# id                                                                         ('a_form_of_repetition', 'UTS02', 10),
# top_explanation_init_strs  a form of repetition, either in the words themselves or in the structure of the phrase
#
#                                                      643  \
# id                         ('a_location', 'UTS02', 136),
# ...
