# %%
import pandas as pd
story_generate = __import__('01_story_generate')

subject = 'UTS02'
rows = story_generate.get_rows_voxels(subject=subject)
rows['top_ngrams_module_correct'] = rows['top_ngrams_module_correct'].apply(lambda x: x[:5])

with pd.option_context('display.max_colwidth', None):
    display(rows[['expl', 'roi_func', 'top_ngrams_module_correct']].style.hide(axis='index'))
# Out:
# len(voxel_nums) 17 nunique 17
# <style type="text/css">
# </style>
# <table id="T_a02c7">
#   <thead>
#     <tr>
#       <th id="T_a02c7_level0_col0" class="col_heading level0 col0" >expl</th>
#       <th id="T_a02c7_level0_col1" class="col_heading level0 col1" >roi_func</th>
#       <th id="T_a02c7_level0_col2" class="col_heading level0 col2" >top_ngrams_module_correct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a02c7_row0_col0" class="data row0 col0" >moments</td>
#       <td id="T_a02c7_row0_col1" class="data row0 col1" >--</td>
#       <td id="T_a02c7_row0_col2" class="data row0 col2" >['the doorbell rang' 'leaves the room' 'enters the room' 'moment later'
#  'suddenly he stops']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row1_col0" class="data row1 col0" >time</td>
#       <td id="T_a02c7_row1_col1" class="data row1 col1" >['PMvh']</td>
#       <td id="T_a02c7_row1_col2" class="data row1 col2" >['count down and' 'three a second' 'weeks became months'
#  'three more seconds' 'forty five second']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row2_col0" class="data row2 col0" >measurements</td>
#       <td id="T_a02c7_row2_col1" class="data row2 col1" >--</td>
#       <td id="T_a02c7_row2_col2" class="data row2 col2" >['fifty feet underwater' 'twenty feet above' 'hundred feet up'
#  'seventy five foot' 'feet above the']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row3_col0" class="data row3 col0" >locations</td>
#       <td id="T_a02c7_row3_col1" class="data row3 col1" >['OPA', 'PMvh', 'V7']</td>
#       <td id="T_a02c7_row3_col2" class="data row3 col2" >['towards the river' 'facing the beach' 'against the railing'
#  'towards the doors' 'onto the sidewalk']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row4_col0" class="data row4 col0" >locations</td>
#       <td id="T_a02c7_row4_col1" class="data row4 col1" >['OPA', 'ATFP']</td>
#       <td id="T_a02c7_row4_col2" class="data row4 col2" >['them fly overhead' 'stand in front' 'across the couch'
#  'onto the sidewalk' 'facing the beach']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row5_col0" class="data row5 col0" >emotion</td>
#       <td id="T_a02c7_row5_col1" class="data row5 col1" >['ATFP']</td>
#       <td id="T_a02c7_row5_col2" class="data row5 col2" >['she started laughing' 'embarrassment she giggled' 'one laughs at'
#  'funny everybody laughs' 'no one laughs']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row6_col0" class="data row6 col0" >emotional expression</td>
#       <td id="T_a02c7_row6_col1" class="data row6 col1" >['PMvh']</td>
#       <td id="T_a02c7_row6_col2" class="data row6 col2" >['and mimed crying' 'she started laughing' 'blocks while screaming'
#  'looked around scared' 'joking and smiling']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row7_col0" class="data row7 col0" >laughter</td>
#       <td id="T_a02c7_row7_col1" class="data row7 col1" >['ATFP', 'AC']</td>
#       <td id="T_a02c7_row7_col2" class="data row7 col2" >['asked i laughed' 'she laughed cause' 'fridge i laughed'
#  'funny everybody laughs' 'of laughed because']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row8_col0" class="data row8 col0" >surprise</td>
#       <td id="T_a02c7_row8_col1" class="data row8 col1" >['ATFP', 'AC']</td>
#       <td id="T_a02c7_row8_col2" class="data row8 col2" >['i provoked gasps' 'asked i laughed' 'felt so betrayed'
#  'suddenly seemed unlikely' 'funny everybody laughs']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row9_col0" class="data row9 col0" >communication</td>
#       <td id="T_a02c7_row9_col1" class="data row9 col1" >['ATFP']</td>
#       <td id="T_a02c7_row9_col2" class="data row9 col2" >['writing his obituary' 'explain the joke' 'read my letter'
#  'who showed me' 'i get interviewed']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row10_col0" class="data row10 col0" >food preparation</td>
#       <td id="T_a02c7_row10_col1" class="data row10 col1" >['ATFP']</td>
#       <td id="T_a02c7_row10_col2" class="data row10 col2" >['sliced cucumber' 'some sliced cucumber' 'buttered slices'
#  'thinly sliced' 'sliced red onion']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row11_col0" class="data row11 col0" >death</td>
#       <td id="T_a02c7_row11_col1" class="data row11 col1" >['PMvh']</td>
#       <td id="T_a02c7_row11_col2" class="data row11 col2" >['the next funeral' 'was saying goodbye' 'sadly she died'
#  'without saying goodbye' 'michael says goodbye']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row12_col0" class="data row12 col0" >negativity</td>
#       <td id="T_a02c7_row12_col1" class="data row12 col1" >['ATFP', 'AC']</td>
#       <td id="T_a02c7_row12_col2" class="data row12 col2" >['fathers feeling marginalized' 'compromise is anathema'
#  'became painfully intimate' 'drinks are unhealthy' 'said very rudely']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row13_col0" class="data row13 col0" >physical injury or trauma</td>
#       <td id="T_a02c7_row13_col1" class="data row13 col1" >--</td>
#       <td id="T_a02c7_row13_col2" class="data row13 col2" >["'s neck snapped" 'snapped his neck' 'lip is split' 'his spine twisted'
#  'throat was slit']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row14_col0" class="data row14 col0" >hair and clothing</td>
#       <td id="T_a02c7_row14_col1" class="data row14 col1" >['PMvh', 'IFSFP']</td>
#       <td id="T_a02c7_row14_col2" class="data row14 col2" >['my black fingernails' 'long shaggy hair' 'hair in pigtails'
#  'pigtails with ribbons' 'rolled up sleeves']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row15_col0" class="data row15 col0" >birthdays</td>
#       <td id="T_a02c7_row15_col1" class="data row15 col1" >['ATFP']</td>
#       <td id="T_a02c7_row15_col2" class="data row15 col2" >['seven my birthday' 'on my birthday' 'sixteenth of october'
#  'fifteenth of april' 'even my birthday']</td>
#     </tr>
#     <tr>
#       <td id="T_a02c7_row16_col0" class="data row16 col0" >rejection</td>
#       <td id="T_a02c7_row16_col1" class="data row16 col1" >['PMvh', 'AC']</td>
#       <td id="T_a02c7_row16_col2" class="data row16 col2" >['crush rejected' 'crush rejected me' 'kissing no flirting'
#  'a sandwich rejected' 'stopped the interview']</td>
#     </tr>
#   </tbody>
# </table>
