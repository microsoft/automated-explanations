# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
story_generate = __import__('01_generate_story')
from sasc.modules.fmri_module import convert_module_num_to_voxel_num
subject = 'UTS02'
setting = 'polysemantic'
rows, _, _ = story_generate.get_rows_and_prompts_default(subject=subject,
    setting=setting,
    seed=1,
    n_examples_per_prompt_to_consider=35,
    n_examples_per_prompt=3,
    version='v5_noun')
rows['top_ngrams_module_correct'] = rows['top_ngrams_module_correct'].apply(lambda x: x[:5])
rows["voxel_num"] = rows.apply(
    lambda row: convert_module_num_to_voxel_num(row["module_num"], row["subject"]),
    axis=1,
)

# with pd.option_context('display.max_colwidth', None):
    # display(rows[['expl', 'roi_func', 'top_ngrams_module_correct']].style.hide(axis='index'))
with pd.option_context('display.max_colwidth', None):
    display(rows[['voxel_num', 'expl', 'roi_func', 'top_ngrams_module_correct']].sort_values(by='voxel_num').style.hide(axis='index'))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# len(vals) 16 nunique voxels 8
# Write the beginning paragraph of a long, coherent story. The story should be about "relationships". Make sure it contains several words related to "relationships", such as ['children an incomprehensibly', 'our vows unimpeachable', 'relationship became depressed'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "movement". Make sure it contains several words related to "movement", such as ['neighbor came over', 'he came downstairs', 'son comes running'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "clothing". Make sure it contains several words related to "clothing", such as ['wearing flower aprons', 'a white handkerchief', 'boots clanking'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "something negative or undesirable". Make sure it contains several words related to "something negative or undesirable", such as ['very conception unnatural', 'became painfully intimate', 'drinks are unhealthy'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "food". Make sure it contains several words related to "food", such as ['sugar cubes', 'some sliced cucumber', 'piece of tomato'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "religion". Make sure it contains several words related to "religion", such as ['a particularly devout', 'attended a prestigious', 'believe however tenuously'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "movement". Make sure it contains several words related to "movement", such as ['job running interference', 'pass the baton', 'stalls i brace'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "food preparation". Make sure it contains several words related to "food preparation", such as ['cut the apples', 'sliced red onion', 'thinly sliced'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "action". Make sure it contains several words related to "action", such as ['became a chemist', 'we washed dishes', 'writing his obituary'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "physical appearance". Make sure it contains several words related to "physical appearance", such as ['back my unibrow', 'long shaggy hair', 'my unibrow'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "location". Make sure it contains several words related to "location", such as ['ship to hoboken', 'hotel across town', 'our small rural'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "silence". Make sure it contains several words related to "silence", such as ['try to sneak', 'become very silent', 'i crawled quietly'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "fear". Make sure it contains several words related to "fear", such as ['runs out crying', 'instinct to hide', 'fled the house'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "moment in time". Make sure it contains several words related to "moment in time", such as ['hour later he', 'suddenly he stops', 'later the doorbell'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "illness". Make sure it contains several words related to "illness", such as ['as paranoid schizophrenic', 'my almost anorexically', 'three month prognosis'].
# Write the next paragraph of the story, staying consistent with the story so far, but now make it about "communication". Make sure it contains several words related to "communication", such as ['me her number', 'they call upstairs', 'tell my friends'].
# <style type="text/css">
# </style>
# <table id="T_e3f45">
#   <thead>
#     <tr>
#       <th id="T_e3f45_level0_col0" class="col_heading level0 col0" >voxel_num</th>
#       <th id="T_e3f45_level0_col1" class="col_heading level0 col1" >expl</th>
#       <th id="T_e3f45_level0_col2" class="col_heading level0 col2" >roi_func</th>
#       <th id="T_e3f45_level0_col3" class="col_heading level0 col3" >top_ngrams_module_correct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3f45_row0_col0" class="data row0 col0" >29226</td>
#       <td id="T_e3f45_row0_col1" class="data row0 col1" >relationships</td>
#       <td id="T_e3f45_row0_col2" class="data row0 col2" >['ATFP', 'AC']</td>
#       <td id="T_e3f45_row0_col3" class="data row0 col3" >['fathers feeling marginalized', 'our vows unimpeachable', 'children an incomprehensibly', 'relationship became painfully', 'relationship became depressed']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row1_col0" class="data row1 col0" >29226</td>
#       <td id="T_e3f45_row1_col1" class="data row1 col1" >something negative or undesirable</td>
#       <td id="T_e3f45_row1_col2" class="data row1 col2" >['ATFP', 'AC']</td>
#       <td id="T_e3f45_row1_col3" class="data row1 col3" >['became painfully intimate', 'drinks are unhealthy', 'said very rudely', 'very conception unnatural', 'i was overreacting']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row2_col0" class="data row2 col0" >35484</td>
#       <td id="T_e3f45_row2_col1" class="data row2 col1" >movement</td>
#       <td id="T_e3f45_row2_col2" class="data row2 col2" >--</td>
#       <td id="T_e3f45_row2_col3" class="data row2 col3" >['neighbor came over', 'enters the room', 'he came downstairs', 'comes walking towards', 'son comes running']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row3_col0" class="data row3 col0" >35484</td>
#       <td id="T_e3f45_row3_col1" class="data row3 col1" >moment in time</td>
#       <td id="T_e3f45_row3_col2" class="data row3 col2" >--</td>
#       <td id="T_e3f45_row3_col3" class="data row3 col3" >['later the doorbell', 'moment later', 'suddenly he stops', 'a minute later', 'hour later he']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row4_col0" class="data row4 col0" >35580</td>
#       <td id="T_e3f45_row4_col1" class="data row4 col1" >religion</td>
#       <td id="T_e3f45_row4_col2" class="data row4 col2" >['pSTS', 'ATFP']</td>
#       <td id="T_e3f45_row4_col3" class="data row4 col3" >['like creationist biology', 'a particularly devout', 'believe however tenuously', 'in this metaphysical', 'boyish almost biblical']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row5_col0" class="data row5 col0" >35580</td>
#       <td id="T_e3f45_row5_col1" class="data row5 col1" >illness</td>
#       <td id="T_e3f45_row5_col2" class="data row5 col2" >['pSTS', 'ATFP']</td>
#       <td id="T_e3f45_row5_col3" class="data row5 col3" >['bipolar obsessive compulsive', 'personality any diagnosis', 'as paranoid schizophrenic', 'three month prognosis', 'suicidal depressed']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row6_col0" class="data row6 col0" >35898</td>
#       <td id="T_e3f45_row6_col1" class="data row6 col1" >movement</td>
#       <td id="T_e3f45_row6_col2" class="data row6 col2" >--</td>
#       <td id="T_e3f45_row6_col3" class="data row6 col3" >['i stopped midstride', 'stalls i brace', 'forward another friend', 'job running interference', 'pass the baton']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row7_col0" class="data row7 col0" >35898</td>
#       <td id="T_e3f45_row7_col1" class="data row7 col1" >communication</td>
#       <td id="T_e3f45_row7_col2" class="data row7 col2" >--</td>
#       <td id="T_e3f45_row7_col3" class="data row7 col3" >['tell her sisters', 'already called ahead', 'tell my friends', 'phone through colleagues', 'skype the unboyfriend']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row8_col0" class="data row8 col0" >46944</td>
#       <td id="T_e3f45_row8_col1" class="data row8 col1" >silence</td>
#       <td id="T_e3f45_row8_col2" class="data row8 col2" >['pSTS', 'PMvh']</td>
#       <td id="T_e3f45_row8_col3" class="data row8 col3" >['sits there silent', 'become very silent', 'room went silent', 'i crawled quietly', 'try to sneak']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row9_col0" class="data row9 col0" >46944</td>
#       <td id="T_e3f45_row9_col1" class="data row9 col1" >fear</td>
#       <td id="T_e3f45_row9_col2" class="data row9 col2" >['pSTS', 'PMvh']</td>
#       <td id="T_e3f45_row9_col3" class="data row9 col3" >['fled the house', 'darted to safety', 'instinct to hide', 'runs out crying', 'could escape quietly']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row10_col0" class="data row10 col0" >51132</td>
#       <td id="T_e3f45_row10_col1" class="data row10 col1" >clothing</td>
#       <td id="T_e3f45_row10_col2" class="data row10 col2" >['ATFP']</td>
#       <td id="T_e3f45_row10_col3" class="data row10 col3" >['shirt the suspenders', 'boots clanking', 'wearing flower aprons', 'a white handkerchief', 'rolled up sleeves']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row11_col0" class="data row11 col0" >51132</td>
#       <td id="T_e3f45_row11_col1" class="data row11 col1" >food</td>
#       <td id="T_e3f45_row11_col2" class="data row11 col2" >['ATFP']</td>
#       <td id="T_e3f45_row11_col3" class="data row11 col3" >['some sliced cucumber', 'piece of tomato', 'lemon slices', 'sugar cubes', 'steamed mussels']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row12_col0" class="data row12 col0" >55978</td>
#       <td id="T_e3f45_row12_col1" class="data row12 col1" >action</td>
#       <td id="T_e3f45_row12_col2" class="data row12 col2" >['ATFP']</td>
#       <td id="T_e3f45_row12_col3" class="data row12 col3" >['we washed dishes', 'shopped the registries', 'became a chemist', 'clean an office', 'writing his obituary']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row13_col0" class="data row13 col0" >55978</td>
#       <td id="T_e3f45_row13_col1" class="data row13 col1" >location</td>
#       <td id="T_e3f45_row13_col2" class="data row13 col2" >['ATFP']</td>
#       <td id="T_e3f45_row13_col3" class="data row13 col3" >['ship to hoboken', 'hotel across town', 'our small rural', 'my whole hometown', 'middlebury vermont']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row14_col0" class="data row14 col0" >59423</td>
#       <td id="T_e3f45_row14_col1" class="data row14 col1" >food preparation</td>
#       <td id="T_e3f45_row14_col2" class="data row14 col2" >['PMvh']</td>
#       <td id="T_e3f45_row14_col3" class="data row14 col3" >['peel and cut', 'thinly sliced', 'cucumber and mayonnaise', 'sliced red onion', 'cut the apples']</td>
#     </tr>
#     <tr>
#       <td id="T_e3f45_row15_col0" class="data row15 col0" >59423</td>
#       <td id="T_e3f45_row15_col1" class="data row15 col1" >physical appearance</td>
#       <td id="T_e3f45_row15_col2" class="data row15 col2" >['PMvh']</td>
#       <td id="T_e3f45_row15_col3" class="data row15 col3" >['skin stripped from', 'rolled up sleeves', 'long shaggy hair', 'back my unibrow', 'that many wrinkles']</td>
#     </tr>
#   </tbody>
# </table>
