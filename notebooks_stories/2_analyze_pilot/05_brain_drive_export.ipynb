# %%
# %load_ext autoreload
# %autoreload 2
import sys
from ridge_utils.DataSequence import DataSequence
import pandas as pd
import os
from os.path import join
from collections import defaultdict
import numpy as np
import joblib
from tqdm import tqdm
from sasc.config import FMRI_DIR, STORIES_DIR, RESULTS_DIR
from neuro.config import brain_drive_resps_dir
from ridge_utils import DataSequence
import ridge_utils.DataSequence import DataSequence
import DataSequence

# %%
wordseqs_dir = join(RESULTS_DIR, 'processed', 'wordseqs')

wordseqs = [
    joblib.load(join(wordseqs_dir, f)) for f in os.listdir(wordseqs_dir)
]
# concatenate list of dicts
wordseqs_dict = {}
for d in wordseqs:
    for k, v in d.items():
        wordseqs_dict[k] = ridge_utils.DataSequence.DataSequence(
            data=v.data, split_inds=v.split_inds, data_times=v.data_times, tr_times=v.tr_times)

# %%
wordseqs_dict

# %%
RESPS_DICT = {
    '20230504': {
        "default/uts02_pilot_gpt4_mar28___ver=v4_noun___seed=1": "GenStory1_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v4_noun___seed=3": "GenStory2_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v4_noun___seed=4": "GenStory3_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v5_noun___seed=1": "GenStory4_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v5_noun___seed=2": "GenStory5_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v5_noun___seed=4": "GenStory6_resps.npy",
    },
    '20230702': {
        "interactions/uts02___jun14___seed=1": "GenStory7_resps.npy",
        "interactions/uts02___jun14___seed=4": "GenStory8_resps.npy",
        "polysemantic/uts02___jun14___seed=6": "GenStory9_resps.npy",
        "polysemantic/uts02___jun14___seed=1": "GenStory10_resps.npy",
    },
    '20231106': {
        'default/uts03___jun14___seed=5': 'GenStory12_resps.npy',
        'default/uts03___jun14___seed=1': 'GenStory13_resps.npy',
        'interactions/uts03___jun14___seed=5': 'GenStory14_resps.npy',
        'interactions/uts03___jun14___seed=6': 'GenStory15_resps.npy',
        'polysemantic/uts03___jun14___seed=3': 'GenStory16_resps.npy',
        'polysemantic/uts03___jun14___seed=7': 'GenStory17_resps.npy',
    },
    '20240509': {
        'default/uts01___may9___seed=5_top1': 'deeptune-story19.npy',
        'default/uts01___may9___seed=2_top2': 'deeptune-story20.npy',
        'interactions/uts01___may9___seed=3_top1': 'deeptune-story21.npy',
        'interactions/uts01___may9___seed=6_top2': 'deeptune-story22.npy',
    },

    '20240604': {
        'roi/uts02___roi_may31___seed=5_best1': 'GenStory23.npy',
        'roi/uts02___roi_may31___seed=2_best2': 'GenStory24.npy',
        'roi/uts02___roi_may31___seed=7_best3': 'GenStory25.npy',
        'roi/uts02___roi_may31___seed=6_best4': 'GenStory26.npy',

        'qa/uts02___qa_may31___seed=1': 'GenStory27_resps.npy',
        'qa/uts02___qa_may31___seed=2': 'GenStory28_resps.npy',
        'qa/uts02___qa_may31___seed=3': 'GenStory29_resps.npy',
    },
}


def build_wordseq(timings):
    TR_TIME = 2
    words = timings['word'].values
    word_lengths = timings['timing'].values
    end_times = timings['time_running'].values

    # Compute the average times of the words (halfway through each word)
    word_avgtimes = end_times - (word_lengths / 2.0)

    # Compute the TR times starting from -9
    tr_times = np.arange(-9, word_avgtimes[-1] + TR_TIME, TR_TIME)

    # Compute the split indices
    split_inds = [(word_avgtimes < (t + TR_TIME)).sum() for t in tr_times][:-1]

    ds = DataSequence(words, split_inds, word_avgtimes, tr_times)
    return ds

# %%
def get_num_from_string(s):
    return int(''.join(filter(str.isdigit, s)))


dset = defaultdict(list)
for session in tqdm(RESPS_DICT.keys()):
    for k, v in RESPS_DICT[session].items():
        dset['session'].append(session)
        dset['story_name'].append(k)
        dset['resp_file'].append(v.replace('_resps', ''))
        # all the time comes from loading the resp here
        resp = np.load(join(brain_drive_resps_dir,
                       session, dset['resp_file'][-1]))
        dset['trs_resp'].append(resp.shape[0])

        if session == '20240509':
            timings = pd.read_csv(
                join(STORIES_DIR, k, 'timings_processed_slowed.csv'))
            # display(timings.head())
        else:
            timings = pd.read_csv(
                join(STORIES_DIR, k, 'timings_processed.csv'))

        # get number from string
        v_string = get_num_from_string(v)
        wordseq = wordseqs_dict[f'GenStory{v_string}']

        # wordseq = build_wordseq(timings)
        if len(wordseq.tr_times) - dset['trs_resp'][-1] == 16:
            # trim off last tr from wordseq
            wordseq.tr_times = wordseq.tr_times[:-1]
        dset['trs_timings'].append(int(max(timings['time_running']) // 2))
        dset['trs_wordseq'].append(len(wordseq.tr_times))
        dset['trs_diff'].append(dset['trs_wordseq'][-1] - dset['trs_resp'][-1])
        dset['subject'].append(k.split('/')[1].split('_')[0].upper())
        dset['wordseq'].append(wordseq)

df = pd.DataFrame(dset)

df['story_id'] = 'GenStory' + df['resp_file'].str.replace(
    '.npy', '').str.replace('GenStory', '').str.replace('deeptune-story', '')
df = df.set_index('story_id')
# Out:
# 100%|██████████| 5/5 [00:36<00:00,  7.36s/it]

# %%
df
# Out:
#              session                                         story_name  \
# story_id
# GenStory1   20230504  default/uts02_pilot_gpt4_mar28___ver=v4_noun__...
# GenStory2   20230504  default/uts02_pilot_gpt4_mar28___ver=v4_noun__...
# GenStory3   20230504  default/uts02_pilot_gpt4_mar28___ver=v4_noun__...
# GenStory4   20230504  default/uts02_pilot_gpt4_mar28___ver=v5_noun__...
# GenStory5   20230504  default/uts02_pilot_gpt4_mar28___ver=v5_noun__...
# GenStory6   20230504  default/uts02_pilot_gpt4_mar28___ver=v5_noun__...
# GenStory7   20230702                interactions/uts02___jun14___seed=1
# GenStory8   20230702                interactions/uts02___jun14___seed=4
# GenStory9   20230702                polysemantic/uts02___jun14___seed=6
# GenStory10  20230702                polysemantic/uts02___jun14___seed=1
# GenStory12  20231106                     default/uts03___jun14___seed=5
# GenStory13  20231106                     default/uts03___jun14___seed=1
# GenStory14  20231106                interactions/uts03___jun14___seed=5
# GenStory15  20231106                interactions/uts03___jun14___seed=6
# GenStory16  20231106                polysemantic/uts03___jun14___seed=3
# GenStory17  20231106                polysemantic/uts03___jun14___seed=7
# GenStory19  20240509                 default/uts01___may9___seed=5_top1
# GenStory20  20240509                 default/uts01___may9___seed=2_top2
# GenStory21  20240509            interactions/uts01___may9___seed=3_top1
# GenStory22  20240509            interactions/uts01___may9___seed=6_top2
# GenStory23  20240604               roi/uts02___roi_may31___seed=5_best1
# GenStory24  20240604               roi/uts02___roi_may31___seed=2_best2
# GenStory25  20240604               roi/uts02___roi_may31___seed=7_best3
# GenStory26  20240604               roi/uts02___roi_may31___seed=6_best4
# GenStory27  20240604                       qa/uts02___qa_may31___seed=1
# GenStory28  20240604                       qa/uts02___qa_may31___seed=2
# GenStory29  20240604                       qa/uts02___qa_may31___seed=3
#
#                        resp_file  trs_resp  trs_timings  trs_wordseq  \
# story_id
# GenStory1          GenStory1.npy       435          445          450
# GenStory2          GenStory2.npy       382          392          397
# GenStory3          GenStory3.npy       322          331          337
# GenStory4          GenStory4.npy       405          415          420
# GenStory5          GenStory5.npy       407          417          422
# GenStory6          GenStory6.npy       470          480          485
# GenStory7          GenStory7.npy       300          309          315
# GenStory8          GenStory8.npy       278          287          293
# GenStory9          GenStory9.npy       373          382          388
# GenStory10        GenStory10.npy       332          341          347
# GenStory12        GenStory12.npy       365          374          380
# GenStory13        GenStory13.npy       430          439          445
# GenStory14        GenStory14.npy       328          337          343
# GenStory15        GenStory15.npy       399          408          414
# GenStory16        GenStory16.npy       301          310          316
# GenStory17        GenStory17.npy       278          287          293
# GenStory19  deeptune-story19.npy       372          376          377
# GenStory20  deeptune-story20.npy       391          395          396
# GenStory21  deeptune-story21.npy       438          442          443
# GenStory22  deeptune-story22.npy       355          359          360
# GenStory23        GenStory23.npy       242          251          257
# GenStory24        GenStory24.npy       255          264          270
# GenStory25        GenStory25.npy       252          261          267
# GenStory26        GenStory26.npy       268          277          283
# GenStory27        GenStory27.npy       482          491          497
# GenStory28        GenStory28.npy       508          517          523
# GenStory29        GenStory29.npy       434          443          449
#
#             trs_diff subject  \
# story_id
# GenStory1         15   UTS02
# GenStory2         15   UTS02
# GenStory3         15   UTS02
# GenStory4         15   UTS02
# GenStory5         15   UTS02
# GenStory6         15   UTS02
# GenStory7         15   UTS02
# GenStory8         15   UTS02
# GenStory9         15   UTS02
# GenStory10        15   UTS02
# GenStory12        15   UTS03
# GenStory13        15   UTS03
# GenStory14        15   UTS03
# GenStory15        15   UTS03
# GenStory16        15   UTS03
# GenStory17        15   UTS03
# GenStory19         5   UTS01
# GenStory20         5   UTS01
# GenStory21         5   UTS01
# GenStory22         5   UTS01
# GenStory23        15   UTS02
# GenStory24        15   UTS02
# GenStory25        15   UTS02
# GenStory26        15   UTS02
# GenStory27        15   UTS02
# GenStory28        15   UTS02
# GenStory29        15   UTS02
#
#                                                       wordseq
# story_id
# GenStory1   <ridge_utils.DataSequence.DataSequence object ...
# GenStory2   <ridge_utils.DataSequence.DataSequence object ...
# GenStory3   <ridge_utils.DataSequence.DataSequence object ...
# GenStory4   <ridge_utils.DataSequence.DataSequence object ...
# GenStory5   <ridge_utils.DataSequence.DataSequence object ...
# GenStory6   <ridge_utils.DataSequence.DataSequence object ...
# GenStory7   <ridge_utils.DataSequence.DataSequence object ...
# GenStory8   <ridge_utils.DataSequence.DataSequence object ...
# GenStory9   <ridge_utils.DataSequence.DataSequence object ...
# GenStory10  <ridge_utils.DataSequence.DataSequence object ...
# GenStory12  <ridge_utils.DataSequence.DataSequence object ...
# GenStory13  <ridge_utils.DataSequence.DataSequence object ...
# GenStory14  <ridge_utils.DataSequence.DataSequence object ...
# GenStory15  <ridge_utils.DataSequence.DataSequence object ...
# GenStory16  <ridge_utils.DataSequence.DataSequence object ...
# GenStory17  <ridge_utils.DataSequence.DataSequence object ...
# GenStory19  <ridge_utils.DataSequence.DataSequence object ...
# GenStory20  <ridge_utils.DataSequence.DataSequence object ...
# GenStory21  <ridge_utils.DataSequence.DataSequence object ...
# GenStory22  <ridge_utils.DataSequence.DataSequence object ...
# GenStory23  <ridge_utils.DataSequence.DataSequence object ...
# GenStory24  <ridge_utils.DataSequence.DataSequence object ...
# GenStory25  <ridge_utils.DataSequence.DataSequence object ...
# GenStory26  <ridge_utils.DataSequence.DataSequence object ...
# GenStory27  <ridge_utils.DataSequence.DataSequence object ...
# GenStory28  <ridge_utils.DataSequence.DataSequence object ...
# GenStory29  <ridge_utils.DataSequence.DataSequence object ...

# %%
joblib.dump(df, join(brain_drive_resps_dir, 'metadata.pkl'))
# Out:
# ['/home/chansingh/mntv1/deep-fMRI/brain_tune/story_data/metadata.pkl']

# %%
df[df.subject == 'UTS03'].story_id.values

# %%
df.loc[['GenStory5', 'GenStory7']]['wordseq'].to_dict()
