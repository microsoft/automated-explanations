# %%
# %load_ext autoreload
# %autoreload 2
import sys
from ridge_utils.DataSequence import DataSequence
import pandas as pd
import os
from os.path import join
from collections import defaultdict
import numpy as np
import joblib
from tqdm import tqdm
from sasc.config import FMRI_DIR, STORIES_DIR
from neuro.config import brain_drive_resps_dir

# %%
RESPS_DICT = {
    '20230504': {
        "default/uts02_pilot_gpt4_mar28___ver=v4_noun___seed=1": "GenStory1_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v4_noun___seed=3": "GenStory2_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v4_noun___seed=4": "GenStory3_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v5_noun___seed=1": "GenStory4_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v5_noun___seed=2": "GenStory5_resps.npy",
        "default/uts02_pilot_gpt4_mar28___ver=v5_noun___seed=4": "GenStory6_resps.npy",
    },
    '20230702': {
        "interactions/uts02___jun14___seed=1": "GenStory7_resps.npy",
        "interactions/uts02___jun14___seed=4": "GenStory8_resps.npy",
        "polysemantic/uts02___jun14___seed=6": "GenStory9_resps.npy",
        "polysemantic/uts02___jun14___seed=1": "GenStory10_resps.npy",
    },
    '20231106': {
        'default/uts03___jun14___seed=5': 'GenStory12_resps.npy',
        'default/uts03___jun14___seed=1': 'GenStory13_resps.npy',
        'interactions/uts03___jun14___seed=5': 'GenStory14_resps.npy',
        'interactions/uts03___jun14___seed=6': 'GenStory15_resps.npy',
        'polysemantic/uts03___jun14___seed=3': 'GenStory16_resps.npy',
        'polysemantic/uts03___jun14___seed=7': 'GenStory17_resps.npy',
    },
    '20240509': {
        'default/uts01___may9___seed=5_top1': 'deeptune-story19.npy',
        'default/uts01___may9___seed=2_top2': 'deeptune-story20.npy',
        'interactions/uts01___may9___seed=3_top1': 'deeptune-story21.npy',
        'interactions/uts01___may9___seed=6_top2': 'deeptune-story22.npy',
    },

    '20240604': {
        'roi/uts02___roi_may31___seed=5_best1': 'GenStory23.npy',
        'roi/uts02___roi_may31___seed=2_best2': 'GenStory24.npy',
        'roi/uts02___roi_may31___seed=7_best3': 'GenStory25.npy',
        'roi/uts02___roi_may31___seed=6_best4': 'GenStory26.npy',

        'qa/uts02___qa_may31___seed=1': 'GenStory27_resps.npy',
        'qa/uts02___qa_may31___seed=2': 'GenStory28_resps.npy',
        'qa/uts02___qa_may31___seed=3': 'GenStory29_resps.npy',
    },
}


def build_wordseq(timings):
    TR_TIME = 2
    words = timings['word'].values
    word_lengths = timings['timing'].values
    end_times = timings['time_running'].values

    # Compute the average times of the words (halfway through each word)
    word_avgtimes = end_times - (word_lengths / 2.0)

    # Compute the TR times starting from -9
    tr_times = np.arange(-9, word_avgtimes[-1] + TR_TIME, TR_TIME)

    # Compute the split indices
    split_inds = [(word_avgtimes < (t + TR_TIME)).sum() for t in tr_times][:-1]

    ds = DataSequence(words, split_inds, word_avgtimes, tr_times)
    return ds

# %%
brain_drive_resps_dir
# Out:
# '/home/chansingh/mntv1/deep-fMRI/brain_tune/story_data'

# %%
dset = defaultdict(list)
for session in tqdm(RESPS_DICT.keys()):
    for k, v in RESPS_DICT[session].items():
        dset['session'].append(session)
        dset['story_name'].append(k)
        dset['resp_file'].append(v.replace('_resps', ''))
        # all the time comes from loading the resp here
        resp = np.load(join(brain_drive_resps_dir,
                       session, dset['resp_file'][-1]))
        dset['trs_resp'].append(resp.shape[0])

        if session == '20240509':
            timings = pd.read_csv(
                join(STORIES_DIR, k, 'timings_processed_slowed.csv'))
            # display(timings.head())
        else:
            timings = pd.read_csv(
                join(STORIES_DIR, k, 'timings_processed.csv'))
        wordseq = build_wordseq(timings)
        if len(wordseq.tr_times) - dset['trs_resp'][-1] == 16:
            # trim off last tr from wordseq
            wordseq.tr_times = wordseq.tr_times[:-1]
        dset['trs_timings'].append(int(max(timings['time_running']) // 2))
        dset['trs_wordseq'].append(len(wordseq.tr_times))
        dset['trs_diff'].append(dset['trs_wordseq'][-1] - dset['trs_resp'][-1])
        dset['subject'].append(k.split('/')[1].split('_')[0].upper())
        dset['wordseq'].append(wordseq)

df = pd.DataFrame(dset)
df['story_id'] = 'Story' + df['resp_file'].str.replace(
    '.npy', '').replace('GenStory', '').replace('deeptune-story', '')


df['story_id'] = 'Story' + df['resp_file'].str.replace(
    '.npy', '').str.replace('GenStory', '').str.replace('deeptune-story', '')
df = df.set_index('story_id')
# Out:
# 100%|██████████| 5/5 [01:04<00:00, 12.83s/it]

# %%
df
# Out:
#            session                                         story_name  \
# story_id
# Story1    20230504  default/uts02_pilot_gpt4_mar28___ver=v4_noun__...
# Story2    20230504  default/uts02_pilot_gpt4_mar28___ver=v4_noun__...
# Story3    20230504  default/uts02_pilot_gpt4_mar28___ver=v4_noun__...
# Story4    20230504  default/uts02_pilot_gpt4_mar28___ver=v5_noun__...
# Story5    20230504  default/uts02_pilot_gpt4_mar28___ver=v5_noun__...
# Story6    20230504  default/uts02_pilot_gpt4_mar28___ver=v5_noun__...
# Story7    20230702                interactions/uts02___jun14___seed=1
# Story8    20230702                interactions/uts02___jun14___seed=4
# Story9    20230702                polysemantic/uts02___jun14___seed=6
# Story10   20230702                polysemantic/uts02___jun14___seed=1
# Story12   20231106                     default/uts03___jun14___seed=5
# Story13   20231106                     default/uts03___jun14___seed=1
# Story14   20231106                interactions/uts03___jun14___seed=5
# Story15   20231106                interactions/uts03___jun14___seed=6
# Story16   20231106                polysemantic/uts03___jun14___seed=3
# Story17   20231106                polysemantic/uts03___jun14___seed=7
# Story19   20240509                 default/uts01___may9___seed=5_top1
# Story20   20240509                 default/uts01___may9___seed=2_top2
# Story21   20240509            interactions/uts01___may9___seed=3_top1
# Story22   20240509            interactions/uts01___may9___seed=6_top2
# Story23   20240604               roi/uts02___roi_may31___seed=5_best1
# Story24   20240604               roi/uts02___roi_may31___seed=2_best2
# Story25   20240604               roi/uts02___roi_may31___seed=7_best3
# Story26   20240604               roi/uts02___roi_may31___seed=6_best4
# Story27   20240604                       qa/uts02___qa_may31___seed=1
# Story28   20240604                       qa/uts02___qa_may31___seed=2
# Story29   20240604                       qa/uts02___qa_may31___seed=3
#
#                      resp_file  trs_resp  trs_timings  trs_wordseq  trs_diff  \
# story_id
# Story1           GenStory1.npy       435          445          450        15
# Story2           GenStory2.npy       382          392          397        15
# Story3           GenStory3.npy       322          331          337        15
# Story4           GenStory4.npy       405          415          420        15
# Story5           GenStory5.npy       407          417          422        15
# Story6           GenStory6.npy       470          480          485        15
# Story7           GenStory7.npy       300          309          315        15
# Story8           GenStory8.npy       278          287          293        15
# Story9           GenStory9.npy       373          382          388        15
# Story10         GenStory10.npy       332          341          347        15
# Story12         GenStory12.npy       365          374          380        15
# Story13         GenStory13.npy       430          439          445        15
# Story14         GenStory14.npy       328          337          343        15
# Story15         GenStory15.npy       399          408          414        15
# Story16         GenStory16.npy       301          310          316        15
# Story17         GenStory17.npy       278          287          293        15
# Story19   deeptune-story19.npy       372          376          382        10
# Story20   deeptune-story20.npy       391          395          402        11
# Story21   deeptune-story21.npy       438          442          448        10
# Story22   deeptune-story22.npy       355          359          365        10
# Story23         GenStory23.npy       242          251          257        15
# Story24         GenStory24.npy       255          264          270        15
# Story25         GenStory25.npy       252          261          267        15
# Story26         GenStory26.npy       268          277          283        15
# Story27         GenStory27.npy       482          491          497        15
# Story28         GenStory28.npy       508          517          523        15
# Story29         GenStory29.npy       434          443          449        15
#
#          subject                                            wordseq
# story_id
# Story1     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story2     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story3     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story4     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story5     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story6     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story7     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story8     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story9     UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story10    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story12    UTS03  <ridge_utils.DataSequence.DataSequence object ...
# Story13    UTS03  <ridge_utils.DataSequence.DataSequence object ...
# Story14    UTS03  <ridge_utils.DataSequence.DataSequence object ...
# Story15    UTS03  <ridge_utils.DataSequence.DataSequence object ...
# Story16    UTS03  <ridge_utils.DataSequence.DataSequence object ...
# Story17    UTS03  <ridge_utils.DataSequence.DataSequence object ...
# Story19    UTS01  <ridge_utils.DataSequence.DataSequence object ...
# Story20    UTS01  <ridge_utils.DataSequence.DataSequence object ...
# Story21    UTS01  <ridge_utils.DataSequence.DataSequence object ...
# Story22    UTS01  <ridge_utils.DataSequence.DataSequence object ...
# Story23    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story24    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story25    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story26    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story27    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story28    UTS02  <ridge_utils.DataSequence.DataSequence object ...
# Story29    UTS02  <ridge_utils.DataSequence.DataSequence object ...

# %%
joblib.dump(df, join(brain_drive_resps_dir, 'metadata.pkl'))
# Out:
# ['/home/chansingh/mntv1/deep-fMRI/brain_tune/story_data/metadata.pkl']

# %%
df[df.subject == 'UTS03'].story_id.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[df.subject == 'UTS03'].story_id.values
#
# File ~/imodelsx/.venv/lib/python3.11/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'story_id'

# %%
df.loc[['GenStory5', 'GenStory7']]['wordseq'].to_dict()
